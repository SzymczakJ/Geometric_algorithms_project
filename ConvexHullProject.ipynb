# %% [markdown]
# # Convex hull project

# %% [markdown]
#  Import data generator

# %%
from random_data.random_data_generator import *

# %% [markdown]
# Import visualization

# %%
from visualization.visualization_tool import *
# %matplotlib notebook

# %% [markdown]
# ---
# ## Random data sets

# %%
random_data = []

# %% [markdown]
# Random points on the range

# %%
range_1 = random_points_on_the_range(20, [-100, 100])

range_2 = random_points_on_the_range(200, [-200, 200])

range_3 = random_points_on_the_range(500, [-500, 500])

range_4 = random_points_on_the_range(1000, [-1000, 1000])

range_5 = random_points_on_the_range(2000, [-2000, 2000])

range_6 = random_points_on_the_range(4000, [-4000, 4000])

range_7 = random_points_on_the_range(8000, [-8000, 8000])

random_data.append((range_2, "range_2"))
random_data.append((range_3, "range_3"))
random_data.append((range_4, "range_4"))
random_data.append((range_5, "range_5"))
random_data.append((range_6, "range_6"))
random_data.append((range_7, "range_7"))

# %% [markdown]
# Random points on the circle

# %%
circle_1 = random_points_on_the_circle(200, [0, 0], 20)

circle_2 = random_points_on_the_circle(500, [0, 0], 50)

circle_3 = random_points_on_the_circle(1000, [0, 0], 100)

circle_4 = random_points_on_the_circle(2000, [0, 0], 200)

circle_5 = random_points_on_the_circle(4000, [0, 0], 400)

circle_6 = random_points_on_the_circle(8000, [0, 0], 800)

random_data.append((circle_1, "circle_1"))
random_data.append((circle_2, "circle_2"))
random_data.append((circle_3, "circle_3"))
random_data.append((circle_4, "circle_4"))
random_data.append((circle_5, "circle_5"))
random_data.append((circle_6, "circle_6"))

# %% [markdown]
# Random points on the rectangle

# %%
rectangle_1 = random_points_on_the_rectangle(200, [(0, 200), (0, 400), (100, 400), (100, 200)])

rectangle_2 = random_points_on_the_rectangle(500, [(0, 500), (0, 1000), (200, 1000), (200, 500)])

rectangle_3 = random_points_on_the_rectangle(1000, [(0, 1000), (0, 2000), (300, 2000), (300, 1000)])

rectangle_4 = random_points_on_the_rectangle(2000, [(0, 2000), (0, 4000), (400, 4000), (400, 2000)])

rectangle_5 = random_points_on_the_rectangle(4000, [(0, 4000), (0, 8000), (500, 8000), (500, 4000)])

rectangle_6 = random_points_on_the_rectangle(8000, [(0, 8000), (0, 10000), (600, 10000), (600, 8000)])

random_data.append((rectangle_1, "rectangle_1"))
random_data.append((rectangle_2, "rectangle_2"))
random_data.append((rectangle_3, "rectangle_3"))
random_data.append((rectangle_4, "rectangle_4"))
random_data.append((rectangle_5, "rectangle_5"))
random_data.append((rectangle_6, "rectangle_6"))

# %% [markdown]
# Random points on the square

# %%
square_1 = random_points_on_square(100, 100, [(0, 0), (0, 100), (100, 100), (100, 0)])

square_2 = random_points_on_square(250, 250, [(0, 0), (0, 250), (250, 250), (250, 0)])

square_3 = random_points_on_square(500, 500, [(0, 0), (0, 500), (500, 500), (500, 0)])

square_4 = random_points_on_square(1000, 1000, [(0, 0), (0, 1000), (1000, 1000), (1000, 0)])

square_5 = random_points_on_square(2000, 2000, [(0, 0), (0, 2000), (2000, 2000), (2000, 0)])

square_6 = random_points_on_square(4000, 4000, [(0, 0), (0, 4000), (4000, 4000), (4000, 0)])

random_data.append((square_1, "square_1"))
random_data.append((square_2, "square_2"))
random_data.append((square_3, "square_3"))
random_data.append((square_4, "square_4"))
random_data.append((square_5, "square_5"))
random_data.append((square_6, "square_6"))

# %% [markdown]
# ---
# # Visualization

# %%
from algorithms_with_visualisation.chan_convex_hull_algorithm import chan_convex_hull as chan
from algorithms_with_visualisation.divide_and_conquer_convex_hull_algorithm import divide_and_conquer as d_and_c
from algorithms_with_visualisation.graham_convex_hull_algorithm import graham_convex_hull as graham
from algorithms_with_visualisation.incremental_convex_hull_algorithm import incremental_convex_hull as incremental
from algorithms_with_visualisation.jarvis_convex_hull_algorithm import jarvis_convex_hull as jarvis
from algorithms_with_visualisation.quickhull_convex_hull_algorithm import quickhull_convex_hull as quickhull
from algorithms_with_visualisation.upper_lower_convex_hull_algorithm import upper_lower_convex_hull as upper_lower

# %% [markdown]
# ## Chan algorithm

# %%
chan_convex_hull, chan_scenes = chan(range_1)
chan_plot = Plot(chan_scenes)
chan_plot.draw()
chan_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(47.21138963362873, -76.15583694245778),
#  (91.35877751294791, 9.689689739921661),
#  (96.72299280936056, 91.1787063024857),
#  (-51.7697019946594, 78.49050805467891),
#  (-73.25504947774292, 12.467224492092626),
#  (-50.757968024740904, -49.146842010717926),
#  (-11.449542069559968, -61.20002524857462)]

# %% [markdown]
# ---
# ## Divide and Conquer algorithm

# %%
d_and_c_convex_hull, d_and_c_scenes = d_and_c(range_1)
d_and_c_plot = Plot(d_and_c_scenes)
d_and_c_plot.draw()
d_and_c_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-50.757968024740904, -49.146842010717926),
#  (-11.449542069559968, -61.20002524857462),
#  (47.21138963362873, -76.15583694245778),
#  (91.35877751294791, 9.689689739921661),
#  (96.72299280936056, 91.1787063024857),
#  (-51.7697019946594, 78.49050805467891),
#  (-73.25504947774292, 12.467224492092626)]

# %% [markdown]
# ---
# ## Graham algorithm

# %%
graham_convex_hull, graham_scenes = graham(range_1)
graham_plot = Plot(graham_scenes)
graham_plot.draw()
graham_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# deque([(47.21138963362873, -76.15583694245778),
#        (91.35877751294791, 9.689689739921661),
#        (96.72299280936056, 91.1787063024857),
#        (-51.7697019946594, 78.49050805467891),
#        (-73.25504947774292, 12.467224492092626),
#        (-50.757968024740904, -49.146842010717926),
#        (-11.449542069559968, -61.20002524857462)])

# %% [markdown]
# ---
# ## Incremental algorithm

# %%
incremental_convex_hull, incremental_scenes = incremental(range_1)
incremental_plot = Plot(incremental_scenes)
incremental_plot.draw()
incremental_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-51.7697019946594, 78.49050805467891),
#  (-73.25504947774292, 12.467224492092626),
#  (-50.757968024740904, -49.146842010717926),
#  (-11.449542069559968, -61.20002524857462),
#  (47.21138963362873, -76.15583694245778),
#  (91.35877751294791, 9.689689739921661),
#  (96.72299280936056, 91.1787063024857)]

# %% [markdown]
# ---
# ## Jarvis algorithm

# %%
jarvis_convex_hull, jarvis_scenes = jarvis(range_1)
jarvis_plot = Plot(jarvis_scenes)
jarvis_plot.draw()
jarvis_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(47.21138963362873, -76.15583694245778),
#  (91.35877751294791, 9.689689739921661),
#  (96.72299280936056, 91.1787063024857),
#  (-51.7697019946594, 78.49050805467891),
#  (-73.25504947774292, 12.467224492092626),
#  (-50.757968024740904, -49.146842010717926),
#  (-11.449542069559968, -61.20002524857462),
#  (47.21138963362873, -76.15583694245778)]

# %% [markdown]
# ---
# ## Quickhull algorithm

# %%
quickhull_convex_hull, quickhull_scenes = quickhull(range_1)
quickhull_plot = Plot(quickhull_scenes)
quickhull_plot.draw()
quickhull_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-73.25504947774292, 12.467224492092626),
#  (-50.757968024740904, -49.146842010717926),
#  (-11.449542069559968, -61.20002524857462),
#  (47.21138963362873, -76.15583694245778),
#  (91.35877751294791, 9.689689739921661),
#  (96.72299280936056, 91.1787063024857),
#  (-51.7697019946594, 78.49050805467891)]

# %% [markdown]
# ---
# ## Upper lower algorithm

# %%
upper_lower_convex_hull, upper_lower_scenes = upper_lower(range_1)
upper_lower_plot = Plot(upper_lower_scenes)
upper_lower_plot.draw()
upper_lower_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-73.25504947774292, 12.467224492092626),
#  (-51.7697019946594, 78.49050805467891),
#  (96.72299280936056, 91.1787063024857),
#  (91.35877751294791, 9.689689739921661),
#  (47.21138963362873, -76.15583694245778),
#  (-11.449542069559968, -61.20002524857462),
#  (-50.757968024740904, -49.146842010717926)]

# %% [markdown]
# # Time comparison

# %%
from time import perf_counter
from math import inf
import pandas as pd

# %%
from algorithms_without_visualisation.chan_convex_hull_algorithm import chan_convex_hull as fast_chan
from algorithms_without_visualisation.divide_and_conquer_convex_hull_algorithm import divide_and_conquer as fast_d_and_c
from algorithms_without_visualisation.graham_convex_hull_algorithm import graham_convex_hull as fast_graham
from algorithms_without_visualisation.incremental_convex_hull_algorithm import incremental_convex_hull as fast_incremental
from algorithms_without_visualisation.jarvis_convex_hull_algorithm import jarvis_convex_hull as fast_jarvis
from algorithms_without_visualisation.quickhull_convex_hull_algorithm import quickhull_convex_hull as fast_quickhull
from algorithms_without_visualisation.upper_lower_convex_hull_algorithm import upper_lower_convex_hull as fast_upper_lower

# %%
def count_time(algorithm, data):
    start = perf_counter()
    algorithm(data)
    end = perf_counter()
    time = end - start
    return time

# %%
def time_comparison(chan, d_and_c, graham, incremental, jarvis, quickhull, upper_lower):
    columns = ["Number of points","Type of points", "Chan", "Divide and conquer", "Graham",
               "Incremental", "Jarvis", "Quickhull", "Upper-lower"]
    data = []
    not_for_d_and_c = [rectangle_1, rectangle_2, rectangle_3, rectangle_4, rectangle_5,
                      rectangle_6, square_1, square_2, square_3, square_4, square_5, square_6]
    for rd, name in random_data:
        chan_time = count_time(chan, rd)
        
        if rd in not_for_d_and_c:
            d_and_c_time = inf
        else:
            d_and_c_time = count_time(d_and_c, rd)
            
        graham_time = count_time(graham, rd)
        
        incremental_time = count_time(incremental, rd)
        
        jarvis_time = count_time(jarvis, rd)
        
        quickhull_time = count_time(quickhull, rd)
        
        upper_lower_time = count_time(upper_lower, rd)
        
        data.append((len(rd), name, chan_time, d_and_c_time, graham_time,
                     incremental_time, jarvis_time, quickhull_time, upper_lower_time))
    return pd.DataFrame(data=data, columns=columns)

# %%
time_comparison_df = time_comparison(fast_chan, fast_d_and_c, fast_graham, fast_incremental,
                                 fast_jarvis, fast_quickhull, fast_upper_lower)
time_comparison_df
# Out:
#     Number of points Type of points      Chan  Divide and conquer    Graham  \
# 0                200        range_2  0.004304            0.001242  0.000984
# 1                500        range_3  0.011087            0.002589  0.003003
# 2               1000        range_4  0.021322            0.004383  0.006189
# 3               2000        range_5  0.027169            0.008644  0.011922
# 4               4000        range_6  0.057822            0.016555  0.024565
# 5               8000        range_7  0.165189            0.041263  0.062925
# 6                200       circle_1  0.004473            0.000793  0.000712
# 7                500       circle_2  0.018301            0.002135  0.002042
# 8               1000       circle_3  0.044166            0.004399  0.004751
# 9               2000       circle_4  0.086505            0.009696  0.010834
# 10              4000       circle_5  0.182621            0.019499  0.023206
# ...
