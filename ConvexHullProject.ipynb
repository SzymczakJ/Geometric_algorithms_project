# %% [markdown]
# # Convex hull project

# %% [markdown]
#  Import data generator

# %%
from random_data.random_data_generator import *

# %% [markdown]
# Import visualization

# %%
from visualization.visualization_tool import *
# %matplotlib notebook

# %% [markdown]
# ---
# ## Random data sets

# %%
random_data = []

# %% [markdown]
# Random points on the range

# %%
range_1 = random_points_on_the_range(20, [-100, 100])

range_2 = random_points_on_the_range(1500, [-200, 200])

range_3 = random_points_on_the_range(3000, [-400, 400])
random_data.append(range_3)

# %% [markdown]
# Random points on the circle

# %%
circle_1 = random_points_on_the_circle(500, [0, 0], 10)

circle_2 = random_points_on_the_circle(1500, [20, 15], 20)

circle_3 = random_points_on_the_circle(3000, [-20, 20], 70)
random_data.append(circle_3)

# %% [markdown]
# Random points on the rectangle

# %%
rectangle_1 = random_points_on_the_rectangle(500, [(0, 0), (0, 10), (10, 10), (10, 0)])

rectangle_2 = random_points_on_the_rectangle(1500, [(20, 100), (20, 250), (120, 250), (120,100)])

rectangle_3 = random_points_on_the_rectangle(3000, [(-30, 50), (-30, 170), (70, 170), (70, 50)])
random_data.append(rectangle_3)

# %% [markdown]
# Random points on the square

# %%
square_1 = random_points_on_square(250, 250, [(0, 0), (0, 10), (10, 10), (10, 0)])

square_2 = random_points_on_square(1000, 500, [(-90, -130), (-90, -20), (0, -20), (0, -130)])

square_3 = random_points_on_square(1200, 1800, [(10, 65), (10, 140), (130, 140), (130, 65)])
random_data.append(square_3)

# %% [markdown]
# ---
# # Visualization

# %%
from algorithms_with_visualisation.chan_convex_hull_algorithm import chan_convex_hull as chan
from algorithms_with_visualisation.divide_and_conquer_convex_hull_algorithm import divide_and_conquer as d_and_c
from algorithms_with_visualisation.graham_convex_hull_algorithm import graham_convex_hull as graham
from algorithms_with_visualisation.incremental_convex_hull_algorithm import incremental_convex_hull as incremental
from algorithms_with_visualisation.jarvis_convex_hull_algorithm import jarvis_convex_hull as jarvis
from algorithms_with_visualisation.quickhull_convex_hull_algorithm import quickhull_convex_hull as quickhull
from algorithms_with_visualisation.upper_lower_convex_hull_algorithm import upper_lower_convex_hull as upper_lower

# %% [markdown]
# ## Chan algorithm

# %%
chan_convex_hull, chan_scenes = chan(range_1)
chan_plot = Plot(chan_scenes)
chan_plot.draw()
chan_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-9.108367309816373, -99.64794510803941),
#  (85.07560562721582, -75.76795651557859),
#  (94.28420965168681, -54.54718483147336),
#  (7.574400069301859, 82.45914472387054),
#  (-70.23852011218521, 72.21114084676535),
#  (-78.12094574065587, 63.053796005691396),
#  (-96.93826479792267, -36.429169127979556),
#  (-77.51725775235742, -94.68417089719843)]

# %% [markdown]
# ---
# ## Divide and Conquer algorithm

# %%
d_and_c_convex_hull, d_and_c_scenes = d_and_c(range_1)
d_and_c_plot = Plot(d_and_c_scenes)
d_and_c_plot.draw()
d_and_c_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-77.51725775235742, -94.68417089719843),
#  (-9.108367309816373, -99.64794510803941),
#  (85.07560562721582, -75.76795651557859),
#  (94.28420965168681, -54.54718483147336),
#  (7.574400069301859, 82.45914472387054),
#  (-70.23852011218521, 72.21114084676535),
#  (-78.12094574065587, 63.053796005691396),
#  (-96.93826479792267, -36.429169127979556)]

# %% [markdown]
# ---
# ## Graham algorithm

# %%
graham_convex_hull, graham_scenes = graham(range_1)
graham_plot = Plot(graham_scenes)
graham_plot.draw()
graham_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# deque([(-9.108367309816373, -99.64794510803941),
#        (85.07560562721582, -75.76795651557859),
#        (94.28420965168681, -54.54718483147336),
#        (7.574400069301859, 82.45914472387054),
#        (-70.23852011218521, 72.21114084676535),
#        (-78.12094574065587, 63.053796005691396),
#        (-96.93826479792267, -36.429169127979556),
#        (-77.51725775235742, -94.68417089719843)])

# %% [markdown]
# ---
# ## Incremental algorithm

# %%
incremental_convex_hull, incremental_scenes = incremental(range_1)
incremental_plot = Plot(incremental_scenes)
incremental_plot.draw()
incremental_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-70.23852011218521, 72.21114084676535),
#  (-78.12094574065587, 63.053796005691396),
#  (-96.93826479792267, -36.429169127979556),
#  (-77.51725775235742, -94.68417089719843),
#  (-9.108367309816373, -99.64794510803941),
#  (85.07560562721582, -75.76795651557859),
#  (94.28420965168681, -54.54718483147336),
#  (7.574400069301859, 82.45914472387054)]

# %% [markdown]
# ---
# ## Jarvis algorithm

# %%
jarvis_convex_hull, jarvis_scenes = jarvis(range_1)
jarvis_plot = Plot(jarvis_scenes)
jarvis_plot.draw()
jarvis_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-9.108367309816373, -99.64794510803941),
#  (-10.108367309816373, -99.64794510803941),
#  (-77.51725775235742, -94.68417089719843),
#  (-96.93826479792267, -36.429169127979556),
#  (-78.12094574065587, 63.053796005691396),
#  (-70.23852011218521, 72.21114084676535),
#  (7.574400069301859, 82.45914472387054),
#  (94.28420965168681, -54.54718483147336),
#  (85.07560562721582, -75.76795651557859),
#  (-9.108367309816373, -99.64794510803941)]

# %% [markdown]
# ---
# ## Quickhull algorithm

# %%
quickhull_convex_hull, quickhull_scenes = quickhull(range_1)
quickhull_plot = Plot(quickhull_scenes)
quickhull_plot.draw()
quickhull_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-96.93826479792267, -36.429169127979556),
#  (-77.51725775235742, -94.68417089719843),
#  (-9.108367309816373, -99.64794510803941),
#  (85.07560562721582, -75.76795651557859),
#  (94.28420965168681, -54.54718483147336),
#  (7.574400069301859, 82.45914472387054),
#  (-70.23852011218521, 72.21114084676535),
#  (-78.12094574065587, 63.053796005691396)]

# %% [markdown]
# ---
# ## Upper lower algorithm

# %%
upper_lower_convex_hull, upper_lower_scenes = upper_lower(range_1)
upper_lower_plot = Plot(upper_lower_scenes)
upper_lower_plot.draw()
upper_lower_convex_hull
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(-96.93826479792267, -36.429169127979556),
#  (-78.12094574065587, 63.053796005691396),
#  (-70.23852011218521, 72.21114084676535),
#  (7.574400069301859, 82.45914472387054),
#  (94.28420965168681, -54.54718483147336),
#  (85.07560562721582, -75.76795651557859),
#  (-9.108367309816373, -99.64794510803941),
#  (-77.51725775235742, -94.68417089719843)]

# %% [markdown]
# # Time comparison

# %%
from time import perf_counter
import pandas as pd

# %%
from algorithms_without_visualisation.chan_convex_hull_algorithm import chan_convex_hull as fast_chan
from algorithms_without_visualisation.divide_and_conquer_convex_hull_algorithm import divide_and_conquer as fast_d_and_c
from algorithms_without_visualisation.graham_convex_hull_algorithm import graham_convex_hull as fast_graham
from algorithms_without_visualisation.incremental_convex_hull_algorithm import incremental_convex_hull as fast_incremental
from algorithms_without_visualisation.jarvis_convex_hull_algorithm import jarvis_convex_hull as fast_jarvis
from algorithms_without_visualisation.quickhull_convex_hull_algorithm import quickhull_convex_hull as fast_quickhull
from algorithms_without_visualisation.upper_lower_convex_hull_algorithm import upper_lower_convex_hull as fast_upper_lower

# %%
def count_time(algorithm, data):
    start = perf_counter()
    algorithm(data)
    end = perf_counter()
    time = end - start
    return time

# %%
def time_comparison(chan, d_and_c, graham, incremental, jarvis, quickhull, upper_lower):
    columns = ["Chan", "Divide and conquer", "Graham", "Incremental", "Jarvis",
               "Quickhull", "Upper-lower"]
    data = []
    for rd in random_data:
#         chan_time = count_time(chan, rd)
        d_and_c_time = count_time(d_and_c, rd)
#         graham_time = count_time(graham, rd)
#         incremental_time = count_time(incremental, rd)
#         jarvis_time = count_time(jarvis, rd)
#         quickhull_time = count_time(quickhull, rd)
        upper_lower_time = count_time(upper_lower, rd)
        chan_time = 0
#         d_and_c_time = 0
        graham_time = 0
        incremental_time = 0
        jarvis_time = 0
        quickhull_time = 0
        upper_lower_time = 0
        data.append((chan_time, d_and_c_time, graham_time, incremental_time,
                     jarvis_time, quickhull_time, upper_lower_time))
    return pd.DataFrame(data=data, columns=columns)

# %%
time_comparison_df = time_comparison(fast_chan, fast_d_and_c, fast_graham, fast_incremental,
                                 fast_jarvis, fast_quickhull, fast_upper_lower)
time_comparison_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-bbb003026e16> in <module>
# ----> 1 time_comparison_df = time_comparison(fast_chan, fast_d_and_c, fast_graham, fast_incremental,
#       2                                  fast_jarvis, fast_quickhull, fast_upper_lower)
#       3 time_comparison_df
#
# <ipython-input-39-bac540c22714> in time_comparison(chan, d_and_c, graham, incremental, jarvis, quickhull, upper_lower)
#       5     for rd in random_data:
#       6 #         chan_time = count_time(chan, rd)
# ----> 7         d_and_c_time = count_time(d_and_c, rd)
#       8 #         graham_time = count_time(graham, rd)
#       9 #         incremental_time = count_time(incremental, rd)
#
# <ipython-input-22-32280d9fdbc6> in count_time(algorithm, data)
#       1 def count_time(algorithm, data):
#       2     start = perf_counter()
# ----> 3     algorithm(data)
#       4     end = perf_counter()
#       5     time = end - start
#
# ~/Studia_AGH/Semestr_3/Geometryczne/Geometric_algorithms_project/algorithms_without_visualisation/divide_and_conquer_convex_hull_algorithm.py in divide_and_conquer(points, epsilon)
#      78         i = 0
#      79         while i + 1 < len(convex_hulls):
# ---> 80             new_convex_hulls.append(merge_hulls(convex_hulls[i], convex_hulls[i + 1], epsilon))
#      81             i += 2
#      82         convex_hulls = new_convex_hulls
#
# ~/Studia_AGH/Semestr_3/Geometryczne/Geometric_algorithms_project/algorithms_without_visualisation/divide_and_conquer_convex_hull_algorithm.py in merge_hulls(left_convex_hull, right_convex_hull, epsilon)
#       4
#       5 def merge_hulls(left_convex_hull, right_convex_hull, epsilon):
# ----> 6     right_n = len(right_convex_hull)
#       7     left_n = len(left_convex_hull)
#       8     rightmost_point = 0
#
# TypeError: object of type 'NoneType' has no len()
